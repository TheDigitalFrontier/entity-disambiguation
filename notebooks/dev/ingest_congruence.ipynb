# %%
import pandas as pd
import numpy as np
import csv
import os

# %% [markdown]
# Charles University master thesis on using the dataset for Named Entity Recognition and Linking: [link](https://is.cuni.cz/webapps/zzp/download/120258144/?lang=cs)

# %%
mydir = '../../data/aida-conll-yago-dataset/'

# %%
tsv_file = open(os.path.join(mydir, "AIDA-YAGO2-DATASET.tsv"))
read_tsv = csv.reader(tsv_file, delimiter="\t")
df = []
for row in read_tsv:
    df.append(row)
acy_df = pd.DataFrame(data=df[1:])
new = ["token", "mention", "full_mention", "YAGO2", "wikipedia_URL", "wikipedia_ID", "freebase"]
acy_df = acy_df.rename(columns=dict(zip(range(7), new)))

# %%
acy_df.head(15)
# Out:
#          token mention     full_mention           YAGO2  \
# 0           EU       B               EU         --NME--
# 1      rejects    None             None            None
# 2       German       B           German         Germany
# 3         call    None             None            None
# 4           to    None             None            None
# 5      boycott    None             None            None
# 6      British       B          British  United_Kingdom
# 7         lamb    None             None            None
# 8            .    None             None            None
# 9         None    None             None            None
# 10       Peter       B  Peter Blackburn         --NME--
# 11   Blackburn       I  Peter Blackburn         --NME--
# 12        None    None             None            None
# 13    BRUSSELS       B         BRUSSELS        Brussels
# 14  1996-08-22    None             None            None
#
#                                   wikipedia_URL wikipedia_ID  freebase
# 0                                          None         None      None
# 1                                          None         None      None
# 2          http://en.wikipedia.org/wiki/Germany        11867  /m/0345h
# 3                                          None         None      None
# 4                                          None         None      None
# 5                                          None         None      None
# 6   http://en.wikipedia.org/wiki/United_Kingdom        31717  /m/07ssc
# 7                                          None         None      None
# 8                                          None         None      None
# 9                                          None         None      None
# 10                                         None         None      None
# 11                                         None         None      None
# 12                                         None         None      None
# 13        http://en.wikipedia.org/wiki/Brussels         3708  /m/0177z
# 14                                         None         None      None

# %%
len(acy_df)
# Out:
# 176615

# %% [markdown]
# Get the sentence number (textual unit, e.g. sentence, paragraph) for each row, using the fact that the token `None` is (nulltype) used as end of sentence marker

# %%
acy_df['unit_number'] = acy_df.token.isnull().cumsum()

# %%
acy_df[['token', 'full_mention', 'unit_number']].head(50)
# Out:
#              token         full_mention  unit_number
# 0               EU                   EU            0
# 1          rejects                 None            0
# 2           German               German            0
# 3             call                 None            0
# 4               to                 None            0
# 5          boycott                 None            0
# 6          British              British            0
# 7             lamb                 None            0
# 8                .                 None            0
# 9             None                 None            1
# 10           Peter      Peter Blackburn            1
# 11       Blackburn      Peter Blackburn            1
# 12            None                 None            2
# 13        BRUSSELS             BRUSSELS            2
# 14      1996-08-22                 None            2
# 15            None                 None            3
# 16             The                 None            3
# 17        European  European Commission            3
# 18      Commission  European Commission            3
# 19            said                 None            3
# 20              on                 None            3
# 21        Thursday                 None            3
# 22              it                 None            3
# 23       disagreed                 None            3
# 24            with                 None            3
# 25          German               German            3
# 26          advice                 None            3
# 27              to                 None            3
# 28       consumers                 None            3
# 29              to                 None            3
# 30            shun                 None            3
# 31         British              British            3
# 32            lamb                 None            3
# 33           until                 None            3
# 34      scientists                 None            3
# 35       determine                 None            3
# 36         whether                 None            3
# 37             mad                 None            3
# 38             cow                 None            3
# 39         disease                 None            3
# 40             can                 None            3
# 41              be                 None            3
# 42     transmitted                 None            3
# 43              to                 None            3
# 44           sheep                 None            3
# 45               .                 None            3
# 46            None                 None            4
# 47         Germany              Germany            4
# 48              's                 None            4
# 49  representative                 None            4

# %% [markdown]
# Drop `None` tokens now, as we no longer need them

# %%
acy_df = acy_df[acy_df.token.notnull()]
len(acy_df)
# Out:
# 164758

# %% [markdown]
# Create single column that holds the full sentence for later use

# %%
acy_df['full_sentence'] = acy_df.groupby('unit_number')['token'].transform(' '.join)
acy_df.head(3)
# Out:
#      token mention full_mention    YAGO2  \
# 0       EU       B           EU  --NME--
# 1  rejects    None         None     None
# 2   German       B       German  Germany
#
#                           wikipedia_URL wikipedia_ID  freebase  unit_number  \
# 0                                  None         None      None            0
# 1                                  None         None      None            0
# 2  http://en.wikipedia.org/wiki/Germany        11867  /m/0345h            0
#
#                                       full_sentence
# 0  EU rejects German call to boycott British lamb .
# 1  EU rejects German call to boycott British lamb .
# 2  EU rejects German call to boycott British lamb .

# %% [markdown]
# Function to spread rolling window of trailing and leading $W$ mentions and their linked entities *within* the same unit of text. I.e. the first mention in sentence two does not include the last mention in sentence one as its trailing mention (rather, its trailing is `None`).

# %%
def spread_unit_neighbours(raw_df, window_size=1):
    
    df = raw_df.copy()

    for w in range(window_size, 0, -1):
        df['m-'+str(w)] = None
        df.loc[df.full_mention.notnull(), 'm-'+str(w)] = df.loc[df.full_mention.notnull(), 'full_mention'].groupby(df['unit_number']).shift(+w)
        df['e-'+str(w)] = None
        df.loc[df.full_mention.notnull(), 'e-'+str(w)] = df.loc[df.full_mention.notnull(), 'wikipedia_ID'].groupby(df['unit_number']).shift(+w)
    for w in range(1, window_size+1):
        df['m+'+str(w)] = None
        df.loc[df.full_mention.notnull(), 'm+'+str(w)] = df.loc[df.full_mention.notnull(), 'full_mention'].groupby(df['unit_number']).shift(-w)
        df['e+'+str(w)] = None
        df.loc[df.full_mention.notnull(), 'e+'+str(w)] = df.loc[df.full_mention.notnull(), 'wikipedia_ID'].groupby(df['unit_number']).shift(-w) 
        
    drop_columns = ['mention', 'YAGO2', 'wikipedia_URL', 'freebase']
    df.drop(drop_columns, axis=1, inplace=True)
    
    return df

# %%
acy_df_neighbours = spread_unit_neighbours(acy_df, 2)
acy_df_neighbours.head(50)
# Out:
#              token         full_mention wikipedia_ID  unit_number  \
# 0               EU                   EU         None            0
# 1          rejects                 None         None            0
# 2           German               German        11867            0
# 3             call                 None         None            0
# 4               to                 None         None            0
# 5          boycott                 None         None            0
# 6          British              British        31717            0
# 7             lamb                 None         None            0
# 8                .                 None         None            0
# 10           Peter      Peter Blackburn         None            1
# 11       Blackburn      Peter Blackburn         None            1
# 13        BRUSSELS             BRUSSELS         3708            2
# 14      1996-08-22                 None         None            2
# 16             The                 None         None            3
# 17        European  European Commission         9974            3
# 18      Commission  European Commission         9974            3
