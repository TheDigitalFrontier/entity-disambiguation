# %%
import sys

import pandas as pd
import numpy as np
import dask.dataframe as dd
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# ## aida-conll-yago-dataset

# %% [markdown]
# Data Description
#
# A dataset for named entity recognition and disambiguation (NERD),
#
# > File Format
# > -----------
# >
# > The format of the final file is the following:
# >
# > - Each document starts with a line: -DOCSTART- (<docid>)
# > - Each following line represents a single token, sentences are separated by an empty line
# >
# > Lines with tabs are tokens the are part of a mention:
# > - column 1 is the token
# > - column 2 is either B (beginning of a mention) or I (continuation of a mention)
# > - column 3 is the full mention used to find entity candidates
# > - column 4 is the corresponding YAGO2 entity (in YAGO encoding, i.e. unicode characters are backslash encoded and spaces are replaced by underscores, see also the tools on the YAGO2 website), OR --NME--, denoting that there is no matching entity in YAGO2 for this particular mention, or that we are missing the connection between the mention string and the YAGO2 entity.
# > - column 5 is the corresponding Wikipedia URL of the entity (added for convenience when evaluating against a Wikipedia based method)
# > - column 6 is the corresponding Wikipedia ID of the entity (added for convenience when evaluating against a Wikipedia based method - the ID refers to the dump used for annotation, 2010-08-17)
# > - column 7 is the corresponding Freebase mid, if there is one (thanks to Massimiliano Ciaramita from Google Zürich for creating the mapping and making it available to us)

# %%
import csv
# df_acy = dd.read_csv('../../aida-conll-yago-dataset/AIDA-YAGO2-DATASET.tsv', sep='\t',dtype='object').compute()
# res = df.infer_objects()

tsv_file = open('../../data/aida-conll-yago-dataset/AIDA-YAGO2-DATASET.tsv')
read_tsv = csv.reader(tsv_file, delimiter="\t")
df = []
for row in read_tsv:
    df.append(row)

# %%
len(df[1])
# Out:
# 4

# %% [markdown]
# **Note:** `wikipedia_ID` in ACY corresponds to `page_id` in KWNLP.

# %%
acy_df = pd.DataFrame(data = df[1:])
new = ['token', 'mention', 'full_mention', 'YAGO2', 'wikipedia_URL', 'wikipedia_ID', 'freebase']
acy_df = acy_df.rename(columns = dict(zip(range(7), new)))
acy_df.head(50)
# Out:
#              token mention         full_mention                YAGO2  \
# 0               EU       B                   EU              --NME--
# 1          rejects    None                 None                 None
# 2           German       B               German              Germany
# 3             call    None                 None                 None
# 4               to    None                 None                 None
# 5          boycott    None                 None                 None
# 6          British       B              British       United_Kingdom
# 7             lamb    None                 None                 None
# 8                .    None                 None                 None
# 9             None    None                 None                 None
# 10           Peter       B      Peter Blackburn              --NME--
# 11       Blackburn       I      Peter Blackburn              --NME--
# 12            None    None                 None                 None
# 13        BRUSSELS       B             BRUSSELS             Brussels
# 14      1996-08-22    None                 None                 None
# 15            None    None                 None                 None
# 16             The    None                 None                 None
# 17        European       B  European Commission  European_Commission
# 18      Commission       I  European Commission  European_Commission
# 19            said    None                 None                 None
# 20              on    None                 None                 None
# 21        Thursday    None                 None                 None
# 22              it    None                 None                 None
# 23       disagreed    None                 None                 None
# 24            with    None                 None                 None
# 25          German       B               German              Germany
# 26          advice    None                 None                 None
# 27              to    None                 None                 None
# 28       consumers    None                 None                 None
# 29              to    None                 None                 None
# 30            shun    None                 None                 None
# 31         British       B              British       United_Kingdom
# 32            lamb    None                 None                 None
# 33           until    None                 None                 None
# 34      scientists    None                 None                 None
# 35       determine    None                 None                 None
# 36         whether    None                 None                 None
# 37             mad    None                 None                 None
# 38             cow    None                 None                 None
# 39         disease    None                 None                 None
# 40             can    None                 None                 None
# 41              be    None                 None                 None
# 42     transmitted    None                 None                 None
# 43              to    None                 None                 None
# 44           sheep    None                 None                 None
# 45               .    None                 None                 None
# 46            None    None                 None                 None
# 47         Germany       B              Germany              Germany
# 48              's    None                 None                 None
# 49  representative    None                 None                 None
#
#                                        wikipedia_URL wikipedia_ID  freebase
# 0                                               None         None      None
# 1                                               None         None      None
# 2               http://en.wikipedia.org/wiki/Germany        11867  /m/0345h
# 3                                               None         None      None
# 4                                               None         None      None
# 5                                               None         None      None
# 6        http://en.wikipedia.org/wiki/United_Kingdom        31717  /m/07ssc
# 7                                               None         None      None
# 8                                               None         None      None
# 9                                               None         None      None
# 10                                              None         None      None
# 11                                              None         None      None
# 12                                              None         None      None
# 13             http://en.wikipedia.org/wiki/Brussels         3708  /m/0177z
# 14                                              None         None      None
# 15                                              None         None      None
# 16                                              None         None      None
# 17  http://en.wikipedia.org/wiki/European_Commission         9974  /m/02q9k
# 18  http://en.wikipedia.org/wiki/European_Commission         9974  /m/02q9k
# 19                                              None         None      None
# 20                                              None         None      None
# 21                                              None         None      None
# 22                                              None         None      None
# 23                                              None         None      None
# 24                                              None         None      None
# 25              http://en.wikipedia.org/wiki/Germany        11867  /m/0345h
# 26                                              None         None      None
# 27                                              None         None      None
# 28                                              None         None      None
# 29                                              None         None      None
# 30                                              None         None      None
# 31       http://en.wikipedia.org/wiki/United_Kingdom        31717  /m/07ssc
# 32                                              None         None      None
# 33                                              None         None      None
# 34                                              None         None      None
# 35                                              None         None      None
# 36                                              None         None      None
# 37                                              None         None      None
# 38                                              None         None      None
# 39                                              None         None      None
# 40                                              None         None      None
# 41                                              None         None      None
# 42                                              None         None      None
# 43                                              None         None      None
# 44                                              None         None      None
# 45                                              None         None      None
# 46                                              None         None      None
# 47              http://en.wikipedia.org/wiki/Germany        11867  /m/0345h
# 48                                              None         None      None
# 49                                              None         None      None

# %%
# Display dataframe with only full_mention values != None
acy_df[acy_df['full_mention'].notna()]
# Out:
#             token mention     full_mention                           YAGO2  \
# 0              EU       B               EU                         --NME--
# 2          German       B           German                         Germany
# 6         British       B          British                  United_Kingdom
# 10          Peter       B  Peter Blackburn                         --NME--
# 11      Blackburn       I  Peter Blackburn                         --NME--
# ...           ...     ...              ...                             ...
# 176583    England       B          England  England_national_football_team
# 176602       1966       B   1966 World Cup             1966_FIFA_World_Cup
# 176603      World       I   1966 World Cup             1966_FIFA_World_Cup
# 176604        Cup       I   1966 World Cup             1966_FIFA_World_Cup
# 176612      Bobby       B            Bobby                  Bobby_Charlton
#
#                                             wikipedia_URL wikipedia_ID  \
# 0                                                    None         None
# 2                    http://en.wikipedia.org/wiki/Germany        11867
# 6             http://en.wikipedia.org/wiki/United_Kingdom        31717
# 10                                                   None         None
# 11                                                   None         None
# ...                                                   ...          ...
# 176583  http://en.wikipedia.org/wiki/England_national_...         9904
# 176602   http://en.wikipedia.org/wiki/1966_FIFA_World_Cup        61629
# 176603   http://en.wikipedia.org/wiki/1966_FIFA_World_Cup        61629
# 176604   http://en.wikipedia.org/wiki/1966_FIFA_World_Cup        61629
# 176612        http://en.wikipedia.org/wiki/Bobby_Charlton         4224
#
#         freebase
# 0           None
# 2       /m/0345h
# 6       /m/07ssc
# 10          None
# 11          None
# ...          ...
# 176583  /m/02pp1
# 176602  /m/0gpjr
# 176603  /m/0gpjr
# 176604  /m/0gpjr
# 176612  /m/01c8x
#
# [29312 rows x 7 columns]

# %%
# Display dataframe with only full_mention values != None
acy_df[acy_df['full_mention'].isna()]
# Out:
#           token mention full_mention YAGO2 wikipedia_URL wikipedia_ID freebase
# 1       rejects    None         None  None          None         None     None
# 3          call    None         None  None          None         None     None
# 4            to    None         None  None          None         None     None
# 5       boycott    None         None  None          None         None     None
# 7          lamb    None         None  None          None         None     None
# ...         ...     ...          ...   ...           ...          ...      ...
# 176609  younger    None         None  None          None         None     None
# 176610  brother    None         None  None          None         None     None
# 176611        ,    None         None  None          None         None     None
# 176613        .    None         None  None          None         None     None
# 176614     None    None         None  None          None         None     None
#
# [147303 rows x 7 columns]

# %%
len(acy_df)
# Out:
# 176615

# %%
print('{:.2f}% of them had a full mention matched'.format(sum([i!=None for i in acy_df.iloc[:, 2]])/len(acy_df)*100))
# Out:
# 16.60% of them had a full mention matched

# %%
print('{:.2f}% of them had a yago2 entity matched'.format(sum([(i!=None and i!='--NME--') for i in acy_df.iloc[:, 3]])/len(acy_df)*100))
# Out:
# 12.60% of them had a yago2 entity matched

# %%
print('{:.2f}% of them had a yago2 entity matched'.format(sum([(i!=None and i!='--NME--') for i in acy_df.iloc[:, 3]])/len(acy_df)*100))
# Out:
# 12.60% of them had a yago2 entity matched

# %%
print('{:.2f}% of them had a wikipedia page matched'.format(sum([i!=None for i in acy_df.iloc[:, 4]])/len(acy_df)*100))
# Out:
# 12.60% of them had a wikipedia page matched

# %%
print('{:.2f}% of them had a freebase mid matched'.format(sum([i!=None for i in acy_df.iloc[:, 6]])/len(acy_df)*100))
# Out:
# 12.60% of them had a freebase mid matched
